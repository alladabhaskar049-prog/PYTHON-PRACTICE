# %%
str = "bhaskar"
print (id(str))
# Out:
# 137308185202336

# %%
str1 = "hello"
str2 = "bhaskar"
print(id(str1)==id (str2))
# Out:
# False

# %%
str1 = 15.1
a = "bhaskar"
b = 10
print(type(str1))
print(type(a))
print(type(b))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'int'>

# %% [markdown]
# stings

# %%
print("MAXY")
# Out:
# MAXY

# %%
a = "maxy"
print(a)
# Out:
# maxy

# %%
S = 'bhaskar'
S = S +"maxy"
print(S)
# Out:
# bhaskarmaxy

# %%
var1 = "MAXY"
var2 = "SATYA"
print("".join([var1, var2]))
# Out:
# MAXYSATYA

# %%
s ="bhaskar"
s=s*10
print(s)
# Out:
# bhaskarbhaskarbhaskarbhaskarbhaskarbhaskarbhaskarbhaskarbhaskarbhaskar

# %% [markdown]
# classes and objects

# %%
class student:
  attr1 = "graduate"
  attr2 = "student"
  def fun(self):
    print("I'M A",self.attr1)
    print("I'M A",self.attr2)
college = student()
print(college.attr1)
college.fun()
# Out:
# graduate
# I'M A graduate
# I'M A student

# %%
class person:
  def __init__(self,name):
    self.name = name
  def say_hi(self):
    print('hello, my name is',self.name)
p = person('john')
p.say_hi()
# Out:
# hello, my name is john

# %%
modules

# %%
import math
A= math.sqrt(16)
print(A)
# Out:
# 4.0

# %%
import math
print(math.sqrt(25))
print(math.pi)
print(math.degrees(2))
print(math.radians(60))
print(math.sin(2))
print(math.factorial(4))
# Out:
# 5.0
# 3.141592653589793
# 114.59155902616465
# 1.0471975511965976
# 0.9092974268256817
# 24

# %%
class person(object):
  def __init__(self , name):
    self.name = name
  def getname(self):
    return self.name
  def isemployee(self):
    return False
class employee(person):
  def isemployee(self):
    return True
